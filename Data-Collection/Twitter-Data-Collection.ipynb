# %% [markdown]
# # Data Collection

# %% [markdown]
# ### Using already available data
#
# - Google datasets https://datasetsearch.research.google.com/
# - Kaggle https://www.kaggle.com/
# - UCI repository https://archive.ics.uci.edu/ml/index.php
# - Paper with code https://paperswithcode.com/
# - NLP Progress http://nlpprogress.com/
# - Other papers https://scholar.google.com/

# %% [markdown]
# ### Collection
#
# - Official data collection method - API
# - Crawling [**Has technical, ethical and legal implications. Details discussed in coming weeks**]

# %% [markdown]
# ## Twitter data collection

# %%
# Install tweepy

# !pip install tweepy

# %%
# Go through Tweepy documentation. https://docs.tweepy.org/en/latest/
# import libraries

import tweepy
import json
# import csv
# import pandas as pd
# import numpy as np
# import time

# %%
# Create a secret_keys.py file and add the values like this:

consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
# import values from secret_keys

from secret_keys import *

# %%
# Stablish connection with API

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# Search end point

searching_word = "#IWD"
search_results = api.search(q=searching_word, count=30)

# %%
search_results
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f43c9d375b0>, _json={'created_at': 'Wed Mar 03 16:09:03 +0000 2021', 'id': 1367145003223556098, 'id_str': '1367145003223556098', 'text': "RT @FoundationSafer: As we countdown to #InternationalWomensDay on 8th March, let's uphold the call for awareness towards gender equality.…", 'truncated': False, 'entities': {'hashtags': [{'text': 'InternationalWomensDay', 'indices': [40, 63]}], 'symbols': [], 'user_mentions': [{'screen_name': 'FoundationSafer', 'name': 'Safer World Foundation', 'id': 1189938563896483842, 'id_str': '1189938563896483842', 'indices': [3, 19]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 741721050, 'id_str': '741721050', '
# ...

# %%
len(search_results)
# Out:
# 30

# %%
one_tweet = search_results[0]._json

# %%
one_tweet
# Out:
# {'created_at': 'Wed Mar 03 16:09:03 +0000 2021',
#  'id': 1367145003223556098,
#  'id_str': '1367145003223556098',
#  'text': "RT @FoundationSafer: As we countdown to #InternationalWomensDay on 8th March, let's uphold the call for awareness towards gender equality.…",
#  'truncated': False,
#  'entities': {'hashtags': [{'text': 'InternationalWomensDay',
#     'indices': [40, 63]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'FoundationSafer',
#     'name': 'Safer World Foundation',
#     'id': 1189938563896483842,
#     'id_str': '1189938563896483842',
#     'indices': [3, 19]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 741721050,
# ...

# %%
result = []
for item in search_results:
    result.append(item._json)

print(result)
# Out:
# [{'created_at': 'Wed Mar 03 14:58:52 +0000 2021', 'id': 1367127339323244554, 'id_str': '1367127339323244554', 'text': 'RT @Limitless_Stree: We salute the front line warriors during the #COVID19 pandemic. \nHere are few women who inspired everyone with their d…', 'truncated': False, 'entities': {'hashtags': [{'text': 'COVID19', 'indices': [66, 74]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Limitless_Stree', 'name': 'Limitless Stree', 'id': 1330783601433088002, 'id_str': '1330783601433088002', 'indices': [3, 19]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://naattuvartha.byethost33.com" rel="nofollow">Naattuvartha</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 952247125185720320, 'id_str': '952247125185720320', 'name': '#StayHome', 'screen_name': 'viralvideovlogs', 'location': 'കേരള
# ...

# %%
len(result)
# Out:
# 30

# %%
search_results[18]._json
# Out:
# {'created_at': 'Wed Mar 03 15:59:44 +0000 2021',
#  'id': 1367142658586607618,
#  'id_str': '1367142658586607618',
#  'text': '❤️❤️We are celebrating all the amazing women this month, we are offering a FREE  toner when you purchase a cleanser… https://t.co/ni2LPWV0gy',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/ni2LPWV0gy',
#     'expanded_url': 'https://twitter.com/i/web/status/1367142658586607618',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://www.later.com" rel="nofollow">LaterMedia</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2871136821,
#   'id_str': '2871136821',
#   'name': 'NotaBeneTweets',
# ...

# %%
one_tweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
one_tweet_entities = one_tweet['entities']

# %%
one_tweet_entities
# Out:
# {'hashtags': [{'text': 'InternationalWomensDay', 'indices': [40, 63]}],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'FoundationSafer',
#    'name': 'Safer World Foundation',
#    'id': 1189938563896483842,
#    'id_str': '1189938563896483842',
#    'indices': [3, 19]}],
#  'urls': []}

# %%
all_hashtags = []

for item in search_results:
    print(item._json['entities']['hashtags'])
# Out:
# [{'text': 'COVID19', 'indices': [66, 74]}]
# [{'text': 'COVID19', 'indices': [66, 74]}]
# [{'text': 'iwd', 'indices': [38, 42]}, {'text': 'gwlp', 'indices': [102, 107]}]
# []
# []
# [{'text': 'InternationalWomensDay', 'indices': [90, 113]}]
# [{'text': 'IWD', 'indices': [33, 37]}]
# []
# []
# [{'text': 'IWD', 'indices': [33, 37]}]
# []
# []
# []
# [{'text': 'IWD', 'indices': [78, 82]}]
# []
# []
# [{'text': 'IWD', 'indices': [134, 138]}]
# [{'text': 'InternationalWomensDay', 'indices': [18, 41]}, {'text': 'IWD', 'indices': [123, 127]}]
# [{'text': 'InternationalWomensDay', 'indices': [37, 60]}, {'text': 'IWD2021', 'indices': [117, 125]}]
# [{'text': 'IWD', 'indices': [65, 69]}]
# [{'text': 'InternationalWomensDay', 'indices': [6, 29]}]
# []
# [{'text': 'IWD', 'indices': [33, 37]}]
# []
# [{'text': 'NASA', 'indices': [83, 88]}]
# [{'text': 'IWD', 'indices': [33, 37]}]
# [{'text': 'iwd', 'indices': [53, 57]}]
# []
# []
# []

# %%
one_tweet['user']
# Out:
# {'id': 952247125185720320,
#  'id_str': '952247125185720320',
#  'name': '#StayHome',
#  'screen_name': 'viralvideovlogs',
#  'location': 'കേരളം',
#  'description': 'news news news and trends\n\nhttps://t.co/2ScZqTGWgG',
#  'url': 'https://t.co/DNSSZ8DfDd',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/DNSSZ8DfDd',
#      'expanded_url': 'https://goo.gl/PrpY6q',
#      'display_url': 'goo.gl/PrpY6q',
#      'indices': [0, 23]}]},
#   'description': {'urls': [{'url': 'https://t.co/2ScZqTGWgG',
#      'expanded_url': 'https://youtu.be/Hxb0CLPBypg',
#      'display_url': 'youtu.be/Hxb0CLPBypg',
#      'indices': [27, 50]}]}},
#  'protected': False,
#  'followers_count': 5768,
#  'friends_count': 4525,
#  'listed_count': 31,
#  'created_at': 'Sat Jan 13 18:33:01 +0000 2018',
#  'favourites_count': 2587,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 581869,
#  'lang': None,
#  'contributors_enabled': False,
# ...

# %%
# Print users followers count

for tweet in search_results:
    data = tweet._json
    print(data['user']['followers_count'])
# Out:
# 5768
# 47
# 1001
# 58
# 8992
# 8380
# 1539
# 117
# 117
# 28967
# 639
# 473
# 390
# 2436
# 117
# 117
# 5733
# 7440
# 218
# 2268
# 944
# 80852
# 288
# 170
# 63
# 918
# 2112
# 7120
# 1147
# 3849

# %%
# store user ids

all_user_ids = []
for tweet in search_results:
    data = tweet._json
    all_user_ids.append(data['user']['id_str'])

# %%
all_user_ids
# Out:
# ['952247125185720320',
#  '2685422455',
#  '739775042972717056',
#  '2462229606',
#  '891360400301858817',
#  '114310898',
#  '18801387',
#  '891974318271463424',
#  '891974318271463424',
#  '558077735',
#  '965000203',
#  '1044626245508427777',
#  '4463360656',
#  '2355038665',
#  '891974318271463424',
#  '891974318271463424',
#  '1081671504088174592',
#  '880505581',
#  '595764902',
#  '21110309',
#  '837430628',
#  '174223715',
#  '855410233744785408',
#  '305747356',
#  '1328260377013067776',
#  '38666265',
#  '129799970',
#  '1087900967591428096',
#  '4230408856',
#  '2368986932']

# %%
user_data = api.get_user(id='18801387')
user_data = user_data._json
user_data.keys()
# Out:
# dict_keys(['id', 'id_str', 'name', 'screen_name', 'location', 'profile_location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'follow_request_sent', 'notifications', 'translator_type'])

# %%
def get_user_with_max_followers(hashtag):
    """
    input : hashtag
    output : information of the user with maximum no. of followers. 
    """

    search_results = api.search(q=hashtag, count=30)
    all_followers = []
    tweets = []
    
    for tweet in search_results:
        data = tweet._json
        followers = data['user']['followers_count']
        all_followers.append(followers)
        tweets.append(data)

    max_no_followers = max(all_followers)
    
    target_person_index = all_followers.index(max_no_followers)
    person_info = tweets[target_person_index]
    user_id = person_info['user']['id_str']

    return api.get_user(id=user_id)._json

# %%
get_user_with_max_followers('IWD')
# Out:
# {'id': 2362618909,
#  'id_str': '2362618909',
#  'name': 'Women Techmakers',
#  'screen_name': 'WomenTechmakers',
#  'location': '',
#  'profile_location': None,
#  'description': "@Google's global program dedicated to helping women thrive in tech through visibility, community, & resources.",
#  'url': 'http://t.co/XaOHNXWSxj',
#  'entities': {'url': {'urls': [{'url': 'http://t.co/XaOHNXWSxj',
#      'expanded_url': 'http://WomenTechmakers.com',
#      'display_url': 'WomenTechmakers.com',
#      'indices': [0, 22]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 125035,
#  'friends_count': 747,
#  'listed_count': 915,
#  'created_at': 'Wed Feb 26 12:30:39 +0000 2014',
#  'favourites_count': 10653,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 4225,
#  'lang': None,
#  'status': {'created_at': 'Wed Mar 03 16:30:00 +0000 2021',
#   'id': 1367150274780033031,
# ...

# %%
data_path = '../data/'

# %%
# Saving the tweets as a text file

def save_tweets_to_text_file(search_tweets, file_name):
    my_list_of_dicts = []
    for each_json_tweet in search_tweets:
        my_list_of_dicts.append(each_json_tweet._json)
        
    with open(data_path + file_name + '.txt', 'w') as file:
        file.write(json.dumps(my_list_of_dicts, indent=4))

# %%
save_tweets_to_text_file(search_results, 'IWD_tweets3')
