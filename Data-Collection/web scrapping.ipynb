# %% [markdown]
# ### Some data collection methods:-
# #### 1. Observations. Making direct observations is a simple and unobtrusive way of collecting data.
# #### 2. Surveys / Questionnaires.
# #### 3. Interviews.
# #### 4. Web Scraping.
# #### 3. Social media analysis eg: collection of various tweets in twitter.

# %% [markdown]
# ##### The data obtained using these data collection methods is used for training and testing data set for our ML model.

# %% [markdown]
# # WEB SCRAPING

# %% [markdown]
# Web Scripting is an automatic method to obtain large amounts of data from websites. Most of this data is unstructured data in an HTML format which is then converted into structured data in a spreadsheet or a database so that it can be used in various applications. There are many different ways to perform web scraping to obtain data from websites. these include using online services, particular API’s or even creating your code for web scraping from scratch. Many large websites like Google, Twitter, Facebook, StackOverflow, etc. have API’s that allow you to access their data in a structured format.

# %%
#pip install beautifulsoup4
#pip install google
#pip install inscriptis

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
query = "summary of the alchemist"
  
for j in search(query, tld="co.in", stop=2, pause=1): 
    print(j)
# Out:
# https://en.wikipedia.org/wiki/The_Alchemist_(novel)
# https://www.sparknotes.com/lit/the-alchemist/summary/

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = j

# %%
data = requests.get(url)
soup = BeautifulSoup(data.text)

# %%
import urllib.request
from inscriptis import get_text
 
url = j
html = urllib.request.urlopen(url).read().decode('utf-8')
 
text = get_text(html)
 
print(text)
# Out:
#         Search all of SparkNotes Search
#
#           Suggestions
#
#           Use up and down arrows to review and enter to select.
#               A Tale of Two Cities Animal Farm Jane Eyre Much Ado About Nothing The Merchant of Venice
#   Menu
#     * No Fear Shakespeare
#     * Literature
#     * Other Subjects
#     * Teacher
#     * Blog
#     * Search
#     * Help
#         Search all of SparkNotes Search
#
#           Suggestions
#
#           Use up and down arrows to review and enter to select.
#               A Tale of Two Cities Animal Farm Jane Eyre Much Ado About Nothing The Merchant of Venice
#     * No Fear Shakespeare
#     * Literature
#     * Other Subjects
#     * Teacher
#     * Blog
#     * Help
#
#     The Alchemist
#
#       Paulo Coelho
#   Study Guide
#       * Study Guide
#   * Summary
#         + Plot Overview
#         + Summary & Analysis
#         + Part One, Section 1
#         + Section 2
#         + Section 3
#         + Section 4
# ...

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <meta http-equiv="x-ua-compatible" content="ie=edge">
# <meta property="og:image" content="https://img.sparknotes.com/sparknotes_new-1200x630.jpg" />
# <link rel="icon" href="/images/favicon.svg" type="image/svg+xml">
# <link rel="icon" type="image/png" href="/images/favicon-32x32.png" sizes="32x32">
# <link rel="apple-touch-icon" sizes="167x167" href="/images/touch-icon-ipad-retina.png">
# <link rel="apple-touch-icon" sizes="180x180" href="/images/touch-icon-iphone-retina.png">
# <link rel="manifest" href="/manifest.json">
# <meta name="theme-color" content="#007ACD">
#
#
#   <title>The Alchemist: Plot Overview | SparkNotes</title>
#
#
#
#   <meta name="description" content="A short summary of Paulo Coelho's The Alchemist This free synopsis covers all the crucial plot points of The Alchemist."> </meta>
#
#
# ...

# %%
quote_divs = soup.find_all("div", attrs={"class": "layout-wrapper-2018"}) #returns a list

# %%
print(quote_divs)
# Out:
# [<div class="layout-wrapper-2018">
# <div class="layout-wrapper-2018__column layout-wrapper-2018__column--main mainTextContent">
# <div class="studyGuideText hack-to-hide-first-h2" id="plotoverview">
# <p>A recurring dream troubles Santiago, a young and adventurous Andalusian shepherd.
#             He has the dream every time he sleeps under a sycamore tree that grows out of the ruins
#             of a church. During the dream, a child tells him to seek treasure at the foot of the
#             Egyptian pyramids. Santiago consults a gypsy woman to interpret the dream, and to his
#             surprise she tells him to go to Egypt. A strange, magical old man named Melchizedek, who
#             claims to be the King of Salem, echoes the gypsy’s advice and tells Santiago that it is
#             his Personal Legend to journey to the pyramids. Melchizedek convinces Santiago to sell
#             his flock and set off to Tangier. When Santiago arrives in Tangier, a thief robs him,
# ...

# %%
quote_div = quote_divs[0] #first element of the list i:e string(plot of the alchemist)

# %%
print(quote_div)
# Out:
# <div class="layout-wrapper-2018">
# <div class="layout-wrapper-2018__column layout-wrapper-2018__column--main mainTextContent">
# <div class="studyGuideText hack-to-hide-first-h2" id="plotoverview">
# <p>A recurring dream troubles Santiago, a young and adventurous Andalusian shepherd.
#             He has the dream every time he sleeps under a sycamore tree that grows out of the ruins
#             of a church. During the dream, a child tells him to seek treasure at the foot of the
#             Egyptian pyramids. Santiago consults a gypsy woman to interpret the dream, and to his
#             surprise she tells him to go to Egypt. A strange, magical old man named Melchizedek, who
#             claims to be the King of Salem, echoes the gypsy’s advice and tells Santiago that it is
#             his Personal Legend to journey to the pyramids. Melchizedek convinces Santiago to sell
#             his flock and set off to Tangier. When Santiago arrives in Tangier, a thief robs him,
# ...

# %%
a = quote_div.text

# %%
print(quote_details)
# Out:
# ['', '', '', 'A recurring dream troubles Santiago, a young and adventurous Andalusian shepherd.', '            He has the dream every time he sleeps under a sycamore tree that grows out of the ruins', '            of a church. During the dream, a child tells him to seek treasure at the foot of the', '            Egyptian pyramids. Santiago consults a gypsy woman to interpret the dream, and to his', '            surprise she tells him to go to Egypt. A strange, magical old man named Melchizedek, who', '            claims to be the King of Salem, echoes the gypsy’s advice and tells Santiago that it is', '            his Personal Legend to journey to the pyramids. Melchizedek convinces Santiago to sell', '            his flock and set off to Tangier. When Santiago arrives in Tangier, a thief robs him,', '            forcing him to find work with a local crystal merchant. The conservative and kindly', '            merchant teaches Santiago several lessons, and Santiago encourages the mer
# ...

# %%
quote_text = quote_details[3:15]

# %%
quote_text
# Out:
# ['A recurring dream troubles Santiago, a young and adventurous Andalusian shepherd.',
#  '            He has the dream every time he sleeps under a sycamore tree that grows out of the ruins',
#  '            of a church. During the dream, a child tells him to seek treasure at the foot of the',
#  '            Egyptian pyramids. Santiago consults a gypsy woman to interpret the dream, and to his',
#  '            surprise she tells him to go to Egypt. A strange, magical old man named Melchizedek, who',
#  '            claims to be the King of Salem, echoes the gypsy’s advice and tells Santiago that it is',
#  '            his Personal Legend to journey to the pyramids. Melchizedek convinces Santiago to sell',
#  '            his flock and set off to Tangier. When Santiago arrives in Tangier, a thief robs him,',
#  '            forcing him to find work with a local crystal merchant. The conservative and kindly',
# ...

# %% [markdown]
# ## Example:

# %% [markdown]
# Extract job info from 'https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia'

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL='https://www.monster.com/jobs/search/?q=Software-Developer&where=Australia'

# %%
page=requests.get(URL)

# %%
soup=BeautifulSoup(page.content, 'html.parser')

# %%
results=soup.find(id='ResultsContainer')

# %%
print(results)
# Out:
# <div class="mux-custom-scroll" data-extend="left" data-mux="customScroll" data-target="html" id="ResultsContainer">
# <div class="scrollable" id="ResultsScrollable">
# <script type="application/ld+json">
#             {"@context":"https://schema.org","@type":"ItemList","mainEntityOfPage":{
#             "@type":"CollectionPage","@id":"https://www.monster.com/jobs/search/?q=Software-Developer&amp;where=Australia"
#             }
#             ,"itemListElement":[
#
#                  {"@type":"ListItem","position":1,"url":"https://job-openings.monster.com/senior-software-engineer-remote-melbourne-vic-us-zuora/8a4e84a4-710d-47a0-b4ba-f5365936b42d"}
#                     ,
#                  {"@type":"ListItem","position":2,"url":""}
#                     ,
#                  {"@type":"ListItem","position":3,"url":"https://job-openings.monster.com/software-engineer-full-stack-sydney-new-south-wales-sydney-nsw-us-mri-software/ce1f83f9-5a3e-403d-8302-01d241783b2d"}
# ...

# %%
print(results.prettify())
# Out:
# <div class="mux-custom-scroll" data-extend="left" data-mux="customScroll" data-target="html" id="ResultsContainer">
#  <div class="scrollable" id="ResultsScrollable">
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"ItemList","mainEntityOfPage":{
#             "@type":"CollectionPage","@id":"https://www.monster.com/jobs/search/?q=Software-Developer&amp;where=Australia"
#             }
#             ,"itemListElement":[
#
#                  {"@type":"ListItem","position":1,"url":"https://job-openings.monster.com/senior-software-engineer-remote-melbourne-vic-us-zuora/8a4e84a4-710d-47a0-b4ba-f5365936b42d"}
#                     ,
#                  {"@type":"ListItem","position":2,"url":""}
#                     ,
#                  {"@type":"ListItem","position":3,"url":"https://job-openings.monster.com/software-engineer-full-stack-sydney-new-south-wales-sydney-nsw-us-mri-software/ce1f83f9-5a3e-403d-8302-01d241783b2d"}
#                     ,
# ...

# %%
job_elems=results.find_all('section',class_='card-content')

# %%
for job_elem in job_elems:
    print(job_elem, end='\n'*2)
# Out:
# <section class="card-content" data-jobid="8a4e84a4-710d-47a0-b4ba-f5365936b42d" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
# <div class="flex-row">
# <div class="mux-company-logo thumbnail"></div>
# <div class="summary">
# <header class="card-header">
# ...

# %%
for job_elem in job_elems:
    title_elem=job_elem.find('h2',class_='title')
    company_elem=job_elem.find('div',class_='company')
    location_elem=job_elem.find('div',class_='location')
    print(title_elem)
    print(company_elem)
    print(location_elem)
    print()
# Out:
# <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="" data-m_impr_j_jawsid="481386668" data-m_impr_j_jobid="2925899" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="0" data-m_impr_j_lid="0" data-m_impr_j_long="0" data-m_impr_j_occid="11970" data-m_impr_j_p="1" data-m_impr_j_postingid="8a4e84a4-710d-47a0-b4ba-f5365936b42d" data-m_impr_j_pvc="a27e93eb-7b58-4913-a011-7ba11af55e6c" data-m_impr_s_t="t" data-m_impr_uuid="2de0c121-1cbf-431d-bd42-8037a1a633f8" href="https://job-openings.monster.com/senior-software-engineer-remote-melbourne-vic-us-zuora/8a4e84a4-710d-47a0-b4ba-f5365936b42d" onclick="clickJobTitle('plid=0&amp;pcid=660&amp;poccid=11970','Software Developer',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Software Engineer - Remote&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Zuor
# ...

# %%
for job_elem in job_elems:
    
    title_elem=job_elem.find('h2',class_='title')
    company_elem=job_elem.find('div',class_='company')
    location_elem=job_elem.find('div',class_='location')
    if None in (title_elem,company_elem,location_elem):
        continue
    print(title_elem.text.strip())
    print(company_elem.text.strip())
    print(location_elem.text.strip())
    print()
# Out:
# Senior Software Engineer - Remote
# Zuora
# Melbourne, VIC
#
# Software Engineer - Full Stack - Sydney, New South Wales
# MRI Software
# Sydney, NSW
#
# Technical Support Engineer 3 (Messaging)
# Twilio
# Melbourne, Victoria, VIC
#
# Technical Support Engineer 3 (Messaging)
# Twilio
# Sydney, New South Wales, NSW
#
# Principal Consultant, Automation & Devops
# Dialog Group
# Sydney, NSW
#
# Customer Experience Technical Analyst - Sydney, New South Wales
# Mediaocean
# Sydney, NSW
#
# Account Executive - APAC
# Uptake
# Perth, Western Australia, Australia
#
# Business Intelligence Specialist
# Jones Lang LaSalle Incorporated
# Sydney, NSW
#
# Senior Talent Acquisition Specialist (Technology) - Sydney
# Randstad Sourceright
# Sydney, NSW
#
# Principal Consultant, Automation & Devops
# Dialog Group
# Melbourne, VIC
#
# Digital Marketing Specialist
# LSG
#
#
# Enterprise Account Executive, ANZ
# Twilio
# Sydney, New South Wales, NSW
#
# Test Automation Engineer
# Dialog Group
# ...
